# %% [markdown]
# # FinanceDataReader 라이브러리 설치

# %%
# !pip install finance-datareader

# %% [markdown]
# # 라이브러리 불러오기

# %%
import FinanceDataReader as fdr

# %% [markdown]
# # KOSPI Index 코스피 지수 데이터

# %%
# 2021-01-01 ~ 현재
df = fdr.DataReader('KS11', '2021')
df
# Out:
#                Open     High      Low    Close      Volume  Change  UpDown  \
# Date
# 2021-01-04  2874.50  2946.54  2869.11  2944.45  1026510465  0.0247       1
# 2021-01-05  2943.67  2990.57  2921.84  2990.57  1519911750  0.0157       1
# 2021-01-06  2993.34  3027.16  2961.37  2968.21  1793418534 -0.0075       2
# 2021-01-07  2980.75  3055.28  2980.75  3031.68  1524654500  0.0214       1
# 2021-01-08  3040.11  3161.11  3040.11  3152.18  1297903388  0.0397       1
# ...             ...      ...      ...      ...         ...     ...     ...
# 2024-02-05  2612.77  2612.77  2562.50  2591.31   511677820 -0.0092       2
# 2024-02-06  2584.20  2599.18  2563.87  2576.20   411617635 -0.0058       2
# 2024-02-07  2592.59  2625.24  2588.09  2609.58   518182343  0.0130       1
# 2024-02-08  2620.26  2629.51  2610.21  2620.32   430009355  0.0041       1
# 2024-02-13  2644.17  2656.87  2640.96  2649.64   559385295  0.0112       1
#
#               Comp          Amount            MarCap
# Date
# ...

# %%
# 2021-01-01 ~ 2022-12-31
df = fdr.DataReader('KS11', '2021-01-01', '2022-12-31')
df
# Out:
#                Open     High      Low    Close      Volume  Change  UpDown  \
# Date
# 2021-01-04  2874.50  2946.54  2869.11  2944.45  1026510465  0.0247       1
# 2021-01-05  2943.67  2990.57  2921.84  2990.57  1519911750  0.0157       1
# 2021-01-06  2993.34  3027.16  2961.37  2968.21  1793418534 -0.0075       2
# 2021-01-07  2980.75  3055.28  2980.75  3031.68  1524654500  0.0214       1
# 2021-01-08  3040.11  3161.11  3040.11  3152.18  1297903388  0.0397       1
# ...             ...      ...      ...      ...         ...     ...     ...
# 2022-12-23  2325.86  2333.08  2311.90  2313.69   366988585 -0.0183       2
# 2022-12-26  2312.54  2321.92  2304.20  2317.14   427844636  0.0015       1
# 2022-12-27  2327.52  2335.99  2321.48  2332.79   448498792  0.0068       1
# 2022-12-28  2296.45  2296.45  2276.90  2280.45   405893520 -0.0224       2
# 2022-12-29  2265.73  2272.67  2236.38  2236.40   361194425 -0.0193       2
#
#               Comp          Amount            MarCap
# Date
# ...

# %% [markdown]
# # 삼성전자 주식시세 가져오기

# %%
# 삼성전자 전체 (1999년 ~ 현재)
df = fdr.DataReader('005930')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1999-10-22   3600   3770   3570   3740    771183       NaN
# 1999-10-25   3710   3720   3580   3590    561313 -0.040107
# 1999-10-26   3530   3690   3509   3640    480149  0.013928
# 1999-10-27   3660   3719   3620   3650    322966  0.002747
# 1999-10-28   3720   3889   3680   3880    807717  0.063014
# ...           ...    ...    ...    ...       ...       ...
# 2024-02-05  74200  74800  73500  74300  19026021 -0.011968
# 2024-02-06  74300  74700  73300  74400  14559254  0.001346
# 2024-02-07  74600  75500  74300  75000  16566445  0.008065
# 2024-02-08  75000  75200  73600  74100  20810708 -0.012000
# 2024-02-13  74800  75200  74400  75200  20508475  0.014845
#
# [6000 rows x 6 columns]

# %%
# CSV로 저장
df.to_csv("samsung.csv")

# %%
# Excel로 저장
df.to_excel("samsung.xlsx")

# %%
# 종가 선택하기
df['Close']
# Out:
# Date
# 1999-10-22     3740
# 1999-10-25     3590
# 1999-10-26     3640
# 1999-10-27     3650
# 1999-10-28     3880
#               ...
# 2024-02-05    74300
# 2024-02-06    74400
# 2024-02-07    75000
# 2024-02-08    74100
# 2024-02-13    75200
# Name: Close, Length: 6000, dtype: int64

# %%
# 종가와 거래량을 함께 선택하기
df[['Close', 'Volume']]
# Out:
#             Close    Volume
# Date
# 1999-10-22   3740    771183
# 1999-10-25   3590    561313
# 1999-10-26   3640    480149
# 1999-10-27   3650    322966
# 1999-10-28   3880    807717
# ...           ...       ...
# 2024-02-05  74300  19026021
# 2024-02-06  74400  14559254
# 2024-02-07  75000  16566445
# 2024-02-08  74100  20810708
# 2024-02-13  75200  20508475
#
# [6000 rows x 2 columns]

# %% [markdown]
# # 주가 데이터 시각화

# %%
df['Close'].plot();

# %%
df['Close'].plot(figsize=(12, 4));

# %%
df[['Close', 'Volume']].plot(figsize=(12, 4));

# %%
df[['Close', 'Volume']].plot(figsize=(12, 4),
                             secondary_y=['Volume']);

# %%
df.loc['2020-01-01':, ['Close', 'Volume']].plot(figsize=(12, 4),
                                                secondary_y=['Volume']);

# %% [markdown]
# [실습 과제] SK하이닉스의 주식시세 데이터를 수집하고, 거래량을 왼쪽 y축에 고가와 저가를 오른쪽 y축에 표시하는 시계열 차트를 생성합니다. (이때, 2023년 3월부터 6월까지 기간으로 한정)

# %%
df = fdr.DataReader('000660')
df.loc['2023-03':'2023-06', ['Volume', 'High', 'Low']].plot(figsize=(12, 5),
                                                            secondary_y=['High', 'Low'],
                                                            mark_right=False);
