# %% [markdown]
# # OpenDartReader 라이브러리 설치

# %%
# !pip install opendartreader

# %% [markdown]
# # 라이브러리 불러오기

# %%
import OpenDartReader

# %% [markdown]
# # 전자공시 접속기 객체 만들기

# %%
# API 인증키 저장
api_key = 'fdfc218d*********************0cabc6e76a'

# %%
# 객체 생성
dart = OpenDartReader(api_key)

# %%
print(dart)

# %% [markdown]
# # 삼성전자 재무제표 가져오기

# %%
data_2022 = dart.finstate('삼성전자', 2022)

# %%
data_2022
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 1   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 2   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 3   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 4   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 5   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 6   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 7   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 8   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 9   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 10  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# ...

# %% [markdown]
# # 매출액 데이터 추출하기

# %%
data_2022.head(2)
# Out:
#          rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 1  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
#
#   sj_div  sj_nm account_nm  ...      thstrm_dt        thstrm_amount frmtrm_nm  \
# 0     BS  재무상태표       유동자산  ...  2022.12.31 현재  218,470,581,000,000    제 53 기
# 1     BS  재무상태표      비유동자산  ...  2022.12.31 현재  229,953,926,000,000    제 53 기
#
#        frmtrm_dt        frmtrm_amount bfefrmtrm_nm   bfefrmtrm_dt  \
# 0  2021.12.31 현재  218,163,185,000,000       제 52 기  2020.12.31 현재
# 1  2021.12.31 현재  208,457,973,000,000       제 52 기  2020.12.31 현재
#
#       bfefrmtrm_amount ord currency
# 0  198,215,579,000,000   1      KRW
# 1  180,020,139,000,000   3      KRW
#
# [2 rows x 21 columns]

# %%
data_2022["account_nm"]
# Out:
# 0           유동자산
# 1          비유동자산
# 2           자산총계
# 3           유동부채
# 4          비유동부채
# 5           부채총계
# 6            자본금
# 7          이익잉여금
# 8           자본총계
# 9            매출액
# 10          영업이익
# 11    법인세차감전 순이익
# 12         당기순이익
# 13     당기순이익(손실)
# 14          유동자산
# 15         비유동자산
# 16          자산총계
# 17          유동부채
# 18         비유동부채
# 19          부채총계
# 20           자본금
# 21         이익잉여금
# 22          자본총계
# 23           매출액
# 24          영업이익
# 25    법인세차감전 순이익
# 26         당기순이익
# 27     당기순이익(손실)
# Name: account_nm, dtype: object

# %%
data_2022["account_nm"] == "매출액"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# Name: account_nm, dtype: bool

# %%
data_2022[data_2022["account_nm"] == "매출액"]
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 9   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 23  20230307000542      11011      2022  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm account_nm  ...                thstrm_dt  \
# 9      IS  손익계산서        매출액  ...  2022.01.01 ~ 2022.12.31
# 23     IS  손익계산서        매출액  ...  2022.01.01 ~ 2022.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 9   302,231,360,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 23  211,867,483,000,000    제 53 기  2021.01.01 ~ 2021.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 9   279,604,799,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 23  199,744,705,000,000       제 52 기  2020.01.01 ~ 2020.12.31
#
#        bfefrmtrm_amount ord currency
# 9   236,806,988,000,000  23      KRW
# 23  166,311,191,000,000  24      KRW
#
# [2 rows x 21 columns]

# %%
(data_2022["account_nm"] == "매출액") & (data_2022["fs_nm"] == "연결재무제표")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# dtype: bool

# %%
data_2022[(data_2022["account_nm"] == "매출액") & (data_2022["fs_nm"] == "연결재무제표")]
# Out:
#          rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 9  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
#
#   sj_div  sj_nm account_nm  ...                thstrm_dt        thstrm_amount  \
# 9     IS  손익계산서        매출액  ...  2022.01.01 ~ 2022.12.31  302,231,360,000,000
#
#   frmtrm_nm                frmtrm_dt        frmtrm_amount bfefrmtrm_nm  \
# 9    제 53 기  2021.01.01 ~ 2021.12.31  279,604,799,000,000       제 52 기
#
#               bfefrmtrm_dt     bfefrmtrm_amount ord currency
# 9  2020.01.01 ~ 2020.12.31  236,806,988,000,000  23      KRW
#
# [1 rows x 21 columns]

# %%
data_2022[(data_2022["account_nm"] == "매출액") & (data_2022["fs_nm"] == "연결재무제표")]["thstrm_amount"]
# Out:
# 9    302,231,360,000,000
# Name: thstrm_amount, dtype: object

# %%
data_2022[(data_2022["account_nm"] == "매출액") & (data_2022["fs_nm"] == "연결재무제표")]["thstrm_amount"].values[0]
# Out:
# '302,231,360,000,000'

# %%
data_2022.loc[(data_2022["account_nm"] == "매출액") & (data_2022["fs_nm"] == "연결재무제표"), "thstrm_amount"]
# Out:
# 9    302,231,360,000,000
# Name: thstrm_amount, dtype: object

# %%
data_2022.loc[(data_2022["account_nm"] == "매출액") & (data_2022["fs_nm"] == "연결재무제표"), "thstrm_amount"].values[0]
# Out:
# '302,231,360,000,000'

# %% [markdown]
# [실습 과제] 2021년 삼성전자의 "별도 재무제표" 영업이익 데이터를 추출합니다.

# %%
data_2021 = dart.finstate('삼성전자', 2021)
data_2021.loc[(data_2021["account_nm"] == "영업이익") & (data_2021["fs_nm"] == "재무제표"), "thstrm_amount"].values[0]
# Out:
# '31,993,162,000,000'
